# %%
from dotenv import load_dotenv
import os

load_dotenv() # charge les variables d'environnement à partir du fichier .env

api_key = os.getenv("WEATHER_API_KEY")

# %%
print(api_key)
# Out:
# 948ec2a69169bca39392009b99161c09

# %%
import requests
import gzip
import json
import io


url = "http://bulk.openweathermap.org/sample/city.list.json.gz"

response = requests.get(url, stream=True)

if response.status_code == 200:
    # lire les données compressées en mémoire
    content = gzip.GzipFile(fileobj=io.BytesIO(response.content)).read()
    
    # décoder les données JSON
    cities = json.loads(content)

    # Extraire les noms des villes avec le code de pays FR
    fr_cities = [city['name'] for city in cities if city['country'] == 'FR']
else:
    print("Error downloading cities list")

# %%
fr_cities
# Out:
# ['Peyrat-le-Château',
#  'Blaye',
#  'Zuydcoote',
#  'Zutkerque',
#  'Zonza',
#  'Zommange',
#  'Zimmersheim',
#  'Zillisheim',
#  'Zicavo',
#  'Zelsheim',
#  'Zegerscappel',
#  'Yzeures-sur-Creuse',
#  'Yzeure',
#  'Yzernay',
#  'Yvré-le-Pôlin',
#  'Yvrandes',
#  'Yvrac',
#  'Yvignac-la-Tour',
#  'Yvetot',
#  'Yves',
#  'Yvelines',
#  'Ytrac',
#  "Arrondissement d'Yssingeaux",
#  'Yssingeaux',
#  'Yssandon',
#  'Yssac-la-Tourette',
#  'Yronde',
#  'Yquelon',
#  'Yport',
#  'Youx',
#  'Yonne',
#  'Yolet',
#  'Ymeray',
#  'Ymare',
#  'Ygrande',
#  'Ygos-Saint-Saturnin',
#  'Yffiniac',
#  'Yèvres',
#  'Yerville',
#  'Yerres',
#  'Yenne',
#  'Yébleron',
#  'Ydes',
#  'Ychoux',
#  'Yainville',
#  'Xonrupt-Longemer',
#  'Xertigny',
#  'Xaintrailles',
#  'Woustviller',
#  'Wormhout',
#  'Wolfisheim',
#  'Wolfgantzen',
#  'Woippy',
#  'Woincourt',
#  'Wizernes',
#  'Wittisheim',
#  'Wittenheim',
#  'Wittelsheim',
#  'Witry-lès-Reims',
#  'Wissous',
#  'Arrondissement de Wissembourg',
#  'Wissembourg',
#  'Wissant',
#  'Wisches',
#  'Wintzenheim',
#  'Winnezeele',
#  'Wingles',
#  'Wingersheim',
#  'Wimmenau',
#  'Wimille',
#  'Wimereux',
#  'Willerwald',
#  'Willems',
#  'Wihr-au-Val',
#  'Wignehies',
#  'Wiesviller',
#  'Widensolen',
#  'Weyersheim',
#  'Wettolsheim',
#  'Westhoffen',
#  'Wervicq-Sud',
#  'Weitbruch',
#  'Waziers',
#  'Wavrin',
#  'Wavrechain-sous-Denain',
#  'Wavignies',
#  'Wattwiller',
#  'Wattrelos',
#  'Wattignies',
#  'Watten',
#  'Wassy',
#  'Wassigny',
#  'Wasselonne',
#  'Wasquehal',
#  'Warmeriville',
#  'Warluis',
#  'Warhem',
#  'Wargnies-le-Grand',
#  'Wardrecques',
#  'Warcq',
#  'Wangenbourg-Engenthal',
#  'Wandignies-Hamage',
#  'Wambrechies',
#  'Walscheid',
#  'Wallers',
#  'Waldighofen',
#  'Walbourg',
#  'Wailly',
#  'Wahagnies',
#  'Vurey',
#  'Vulaines-sur-Seine',
#  'Vue',
#  'Vrigne-aux-Bois',
#  'Vred',
#  'Vozelles',
#  'Voves',
#  'Vouzon',
#  'Arrondissement de Vouziers',
#  'Vouziers',
#  'Vouvray',
#  'Voutezac',
#  'Vourzac',
#  'Vourles',
#  'Vourey',
#  'Vouneuil-sur-Vienne',
#  'Vouneuil-sous-Biard',
#  'Voulx',
#  'Voulangis',
#  'Voujeaucourt',
#  'Vouilly',
#  'Vouillé',
#  'Vouillé',
#  'Vouharte',
#  'Vougy',
#  'Vougy',
#  'Vouécourt',
#  'Vosges',
#  'Vorton',
#  'Vorey',
#  'Voreppe',
#  'Vonnas',
#  'Volx',
#  'Volvic',
#  'Volstroff',
#  'Volonne',
#  'Volmerange-les-Mines',
#  'Vollore-Ville',
#  'Voisins-le-Bretonneux',
#  'Voisenon',
#  'Voiron',
#  'Voglans',
#  'Vœuil-et-Giget',
#  'Vodable',
#  'Vizille',
#  'Vix',
#  'Vivy',
#  'Vivonne',
#  'Viviez',
#  'Viviers-lès-Montagnes',
#  'Viviers',
#  'Vivier-au-Court',
#  'Viverols',
#  'Viven',
#  'Viuz-la-Chiésaz',
#  'Viuz-en-Sallaz',
#  'Vittel',
#  'Vitteaux',
#  'Vitry-sur-Seine',
#  'Vitry-sur-Orne',
#  'Arrondissement de Vitry-le-François',
#  'Vitry-le-François',
#  'Vitry-en-Artois',
#  'Vitry-aux-Loges',
#  'Vitrolles',
#  'Vitré',
#  'Vitray-sous-Brézolles',
#  'Vitrac',
#  'Vitrac',
#  'Visan',
#  'Viry-Noureuil',
#  'Viry-Châtillon',
#  'Viry',
#  'Virsac',
#  'Viroflay',
#  'Viriville',
#  'Virieu-le-Grand',
#  'Virieu',
#  'Viriat',
#  'Virey',
#  'Virey-le-Grand',
#  'Vireux-Wallerand',
#  'Vireux-Molhain',
#  'Virenne',
#  'Virelade',
#  'Arrondissement de Vire',
#  'Vire',
#  'Virazeil',
#  'Viplaix',
#  'Vion',
#  'Violès',
#  'Violay',
#  'Violaines',
#  'Vinzelles',
#  'Vinzelles',
#  'Vinsobres',
#  'Vinon-sur-Verdon',
#  'Vinneuf',
#  'Vingt-Hanaps',
#  'Vineuil-Saint-Firmin',
#  'Vineuil',
#  'Vineuil',
#  'Vines',
#  'Vindefontaine',
#  'Vincey',
#  'Vincennes',
#  'Vinça',
#  'Vinay',
#  'Vinassan',
#  'Vimy',
#  'Vimoutiers',
#  'Vimory',
#  'Vimont',
#  'Vimines',
#  'Villy-Bocage',
#  'Villouxel',
#  'Villons-les-Buissons',
#  'Villiers-sur-Orge',
#  'Villiers-sur-Morin',
#  'Villiers-sur-Marne',
#  'Villiers-sur-Loir',
#  'Villiers-sous-Mortagne',
#  'Villiers-Saint-Georges',
#  'Villiers-Saint-Fréderic',
#  'Villiers-le-Morhier',
#  'Villiers-le-Bel',
#  'Villiers-le-Bâcle',
#  'Villiers-Fossard',
#  'Villiers-en-Plaine',
#  'Villiers-en-Lieu',
#  'Villié-Morgon',
#  'Villey-Saint-Étienne',
#  'Villevocance',
#  'Villevieille',
#  'Villeveyre',
#  'Villeveyrac',
#  'Villevêque',
#  'Villevaudé',
#  'Villeurbanne',
#  'Villette-de-Vienne',
#  'Villetoureix',
#  'Villetelle',
#  'Villetaneuse',
#  'Villes-sur-Auzon',
#  'Ville-sous-la-Ferté',
#  'Ville-sous-Anjou',
#  'Villerville',
#  'Villerupt',
#  'Villers-sur-Mer',
#  'Villers-sur-Coudun',
#  'Villers-sous-Saint-Leu',
#  'Villers-Semeuse',
#  'Villers-Saint-Paul',
#  'Villers-Pol',
#  'Villers-Outréaux',
#  'Villers-lès-Nancy',
#  'Villers-le-Lac',
#  'Villers-la-Montagne',
#  'Villersexel',
#  'Villers-en-Ouche',
#  'Villers-en-Cauchies',
#  'Villers-Écalles',
#  'Villers-Cotterêts',
#  'Villers-Canivet',
#  'Villers-Bretonneux',
#  'Villers-Bocage',
#  'Villers-Bocage',
#  'Villers-au-Tertre',
#  'Villereversure',
#  'Villerest',
#  'Villeréal',
#  'Villepreux',
#  'Villepinte',
#  'Villepinte',
#  'Villeparisis',
#  'Villenoy',
#  'Villenouvelle',
#  'Villennes-sur-Seine',
#  'Villeneuve-Tolosane',
#  'Villeneuve-sur-Yonne',
#  'Arrondissement de Villeneuve-sur-Lot',
#  'Villeneuve-sur-Lot',
#  'Villeneuve-sur-Bellot',
#  'Villeneuve-sur-Allier',
#  'Villeneuve-Saint-Germain',
#  'Villeneuve-Saint-Georges',
#  'Villeneuve-Loubet',
#  'Villeneuve-les-Sablons',
#  'Villeneuve-lès-Maguelone',
#  'Villeneuve-lès-Bouloc',
#  'Villeneuve-lès-Béziers',
#  'Villeneuve-lès-Avignon',
#  'Villeneuve-le-Roi',
#  'Villeneuve-le-Comte',
#  'Villeneuve-la-Rivière',
#  'Villeneuve-la-Guyard',
#  'Villeneuve-la-Garenne',
#  'Villeneuve-la-Comptal',
#  'Villeneuve-de-Rivière',
#  'Villeneuve-de-Marsan',
#  'Villeneuve-de-la-Raho',
#  'Villeneuve-de-Duras',
#  'Villeneuve-de-Berg',
#  'Villeneuve',
#  "Villeneuve-d'Ascq",
#  'Villeneuve',
#  'Villeneuve',
#  'Villeneuve',
#  "Villenave-d'Ornon",
#  'Villenave-de-Rions',
#  'Villenave',
#  'Villenauxe-la-Grande',
#  'Villemur-sur-Tarn',
#  'Villemoustaussou',
#  'Villemomble',
#  'Villemolaque',
#  'Villemoisson-sur-Orge',
#  'Villemoirieu',
#  'Villemeux-sur-Eure',
#  'Villemandeur',
#  'Villemade',
#  'Vilallonga dels Monts',
#  'Villelongue-de-la-Salanque',
#  'Villelaure',
#  'Ville-la-Grand',
#  'Villejust',
#  'Villejuif',
#  'Villejacques',
#  'Villegouge',
#  'Villegailhenc',
#  'Villefranque',
#  'Arrondissement de Villefranche-sur-Saône',
#  'Villefranche-sur-Saône',
#  'Villefranche-sur-Mer',
#  'Villefranche-du-Queyran',
#  'Villefranche-du-Périgord',
#  'Arrondissement de Villefranche-de-Rouergue',
#  'Villefranche-de-Rouergue',
#  'Villefranche-de-Lonchat',
#  'Villefranche-de-Lauragais',
#  'Villefranche-sur-Cher',
#  'Villefontaine',
#  'Villefagnan',
#  'Villedômer',
#  'Villedieu-sur-Indre',
#  'Villedieu-les-Poêles',
#  'Villedieu-lès-Bailleul',
#  'Villedieu-la-Blouère',
#  'Paris',
#  "Ville-d'Avray",
#  'Villecroze',
#  'Villecresnes',
#  'Villechien',
#  'Villebret',
#  'Villebramar',
#  'Villebon-sur-Yvette',
#  'Villebois-les-Pins',
#  'Villebois',
#  'Villeblevin',
#  'Villebernier',
#  'Villebaudon',
#  'Villebarou',
#  'Villebadin',
#  'Villé',
#  'Villaz',
#  'Villaudric',
#  'Villasavary',
#  'Villars-les-Dombes',
#  'Villar-Saint-Pancrace',
#  'Villars',
#  'Villars',
#  'Villargondran',
#  'Villard-de-Lans',
#  'Villard-Bonnot',
#  'Villandry',
#  'Villandraut',
#  'Villaines-la-Juhel',
#  'Village-Neuf',
#  'Villabé',
#  'Vilcey-sur-Trey',
#  'Vihiers',
#  'Vigy',
#  'Vigouroux',
#  'Vigny',
#  'Vigny',
#  'Vignoux-sur-Barangeon',
#  'Vignot',
#  'Vignonet',
#  'Vignoc',
#  'Vigneux-sur-Seine',
#  'Vigneux-de-Bretagne',
#  'Vigneulles-lès-Hattonchâtel',
#  'Vignats',
#  'Vignale',
#  'Vignacourt',
#  'Vigeois',
#  'Arrondissement du Vigan',
#  'Vif',
#  'Vieux-Thann',
#  'Vieux-Pont',
#  'Vieux-Mareuil',
#  'Le Vieux-Marché',
#  'Vieux-Lixheim',
#  'Vieux-Condé',
#  'Vieux-Charmont',
#  'Vieux-Boucau-les-Bains',
#  'Vieux-Berquin',
#  'Vieux',
#  'Vieure',
#  'Viesly',
#  'Vierzon-Village',
#  'Vierzon',
#  'Vienne-en-Val',
#  'Vienne',
#  'Arrondissement de Vienne',
#  'Vienne',
#  'Viennay',
#  'Vielmur-sur-Agout',
#  'Vielle-Tursan',
#  'Vielle-Soubiran',
#  'Vielleségure',
#  'Vielle-Saint-Girons',
#  "Viellenave-d'Arthez",
#  'Vieillevigne',
#  'Vieille-Toulouse',
#  'Vieille-Église',
#  'Vieille-Brioude',
#  'Videcosville',
#  'Vidauban',
#  'Victot-Pontfol',
#  'Vic-sur-Seille',
#  'Vic-sur-Cère',
#  'Vic-sur-Aisne',
#  'Vicques',
#  'Vicq-sur-Breuilh',
#  "Vicq-d'Auribat",
#  'Vicq',
#  'Vicq',
#  'Vico',
#  'Vic-le-Comte',
#  'Vic-la-Gardiole',
#  'Arrondissement de Vichy',
#  'Vichy',
#  'Vic-Fezensac',
#  'Vic-en-Bigorre',
#  'Vibraye',
#  'Vias',
#  'Viarmes',
#  'Vianne',
#  'Vialette',
#  'Vialer',
#  'Viale',
#  'Vialard',
#  'Vezins',
#  'Vezin-le-Coquet',
#  'Vézézoux',
#  'Vézénobres',
#  'Vézelise',
#  'Vèze',
#  'Veyrines-de-Domme',
#  'Veyrignac',
#  'Veyrier-du-Lac',
#  'Veyre-Monton',
#  'Veyre',
#  'Veyras',
#  'Veyrac',
#  'Veynes',
#  'Veurey-Voroize',
#  'Vétraz-Monthoux',
#  'Vestric-et-Candiac',
#  'Vessey',
#  'Vesseaux',
#  'Arrondissement de Vesoul',
#  'Vesoul',
#  'Vesly',
#  'Vescovato',
#  'Verzy',
#  'Verzun le Bas',
#  'Verzenay',
#  'Arrondissement de Vervins',
#  'Vervins',
#  'Vertus',
#  'Vert-Saint-Denis',
#  'Vertou',
#  'Verton',
#  'Vertolaye',
#  'Vert-le-Petit',
#  'Vert-le-Grand',
#  'Vertheuil',
#  "Verteuil-d'Agenais",
#  'Vert-en-Drouais',
#  'Vertaizon',
#  'Ver-sur-Mer',
#  'Ver-sur-Launette',
#  'Versonnex',
#  'Verson',
#  'Versainville',
#  'Arrondissement de Versailles',
#  'Versailles',
#  'Verrières-le-Buisson',
#  'Verrières',
#  'Verrières',
#  'Verquin',
#  'Véron',
#  'Verny',
#  'Vern-sur-Seiche',
#  'Vernoux-en-Vivarais',
#  'Vernou-la-Celle-sur-Seine',
#  'Vernou-sur-Brenne',
#  'Vernouillet',
#  'Vernouillet',
#  'Vernouillet',
#  'Vernosc-lès-Annonay',
#  'Vernon',
#  'Vernols',
#  'Vernoil-le-Fourrier',
#  'Vernix',
#  'Vernioz',
#  'Verniolle',
#  'Vernines',
#  'Verneuil-sur-Vienne',
#  'Verneuil-sur-Seine',
#  'Verneuil-sur-Avre',
#  'Verneuil-en-Halatte',
#  'Verneuge',
#  'Vernet-les-Bains',
#  'Vernet-la-Varenne',
#  'Vernet',
#  'Verneix',
#  'Vernègues',
#  'Vernassal',
#  'Vernantes',
#  'Vernaison',
#  'Vermenton',
#  'Vermelles',
#  'Vermand',
#  'Verlinghem',
#  'Vérines',
#  'Vergt-de-Biron',
#  'Vergt',
#  'Vergongheon',
#  'Vergoncey',
#  'Vergigny',
#  'Vergèze',
#  'Verfeil',
#  'Véretz',
#  'Verdun',
#  'Verdun-sur-le-Doubs',
#  'Verdun-sur-Garonne',
#  'Arrondissement de Verdun',
#  'Verdon',
#  'Verdets',
#  'Verdelais',
#  'Verchaix',
#  'Vercel-Villedieu-le-Camp',
#  'Verberie',
#  'Vérac',
#  'Ventiseri',
#  'Venteuges',
#  'Ventabren',
#  'Vensat',
#  'Vensac',
#  'Venoy',
#  'Vennecy',
#  'Venizel',
#  'Vénissieux',
#  'Vengeons',
#  'Veneux-les-Sablons',
#  'Venette',
#  'Venerque',
#  'Venelles',
#  'Vénéjan',
#  'Vendres',
#  'Vendrennes',
#  'Arrondissement de Vendôme',
#  'Vendôme',
#  'Vendœuvres',
#  'Vendin-le-Vieil',
#  'Vendin-lès-Béthune',
#  'Vendeville',
#  'Vendeuvre-sur-Barse',
#  'Vendeuvre-du-Poitou',
#  'Vendeuvre',
#  'Vendes',
#  'Vendenheim',
#  'Vendegies-sur-Écaillon',
#  'Vendée',
#  'Vendays-Montalivet',
#  'Vendat',
#  'Vendargues',
#  'Vence',
#  'Venasque',
#  'Venas',
#  'Venarey-les-Laumes',
#  'Venansault',
#  'Vémars',
#  'Velzic',
#  'Velleron',
#  'Vélizy-Villacoublay',
#  'Vélines',
#  'Velaux',
#  'Velars-sur-Ouche',
#  'Velaines',
#  'Velaine-en-Haye',
#  'Veigy',
#  'Veigné',
#  'Védrines',
#  'Védrenne',
#  'Vedène',
#  'Vecoux',
#  'Veauche',
#  'Vazerac',
#  'Vazeilles-près-Saugues',
#  'Vayres',
#  'Vayrac',
#  'Vay',
#  'Vavray-le-Grand',
#  'Vauzelle',
#  'Vaux-sur-Seulles',
#  'Vaux-sur-Seine',
#  'Vaux-sur-Mer',
#  'Vaux-sur-Aure',
#  'Vaux-le-Pénil',
#  'Vaux-en-Bugey',
#  'Vaux',
#  'Vauville',
#  'Vauvert',
#  'Vauréal',
#  'Vaunoise',
#  'Vaumoise',
#  'Vaumas',
#  'Vaulx-Vraucourt',
#  'Vaulx-Milieu',
#  'Vaulx-en-Velin',
#  'Vaulnaveys-le-Haut',
#  'Vaulnaveys-le-Bas',
#  'Vaujours',
#  'Vauhallan',
#  'Vaugrigneuse',
#  'Vaugneray',
#  'Vaudry',
#  'Vaudrimesnil',
#  'Vaudeloges',
#  'Vaudelnay',
#  'Vaucresson',
#  'Vaucouleurs',
#  'Vaucluse',
#  'Vauchrétien',
#  'Vatan',
#  'Vasteville',
#  'Vassy',
#  'Vassivière',
#  'Vasselay',
#  'Vassel',
#  'Vasles',
#  'Varzy',
#  'Vars',
#  'Varreddes',
#  'Varrains',
#  'Varois-et-Chaignot',
#  'Varilhes',
#  'Varetz',
#  'Varennes-sur-Usson',
#  'Varennes-sur-Tèche',
#  'Varennes-sur-Seine',
#  'Varennes-sur-Morge',
#  'Varennes-sur-Loire',
#  'Varennes-sur-Allier',
#  'Varennes-Saint-Sauveur',
#  'Varennes-le-Grand',
#  'Varennes-Jarcy',
#  'Varenguebec',
#  'Varengeville-sur-Mer',
#  'Varaville',
#  'Varangéville',
#  'Varaignes',
#  'Varades',
#  'Var',
#  'Vanxains',
#  'Vanves',
#  'Arrondissement de Vannes',
#  'Vannes',
#  'Vandœuvre-lès-Nancy',
#  'Valvins',
#  'Valuéjols',
#  'Vals-près-le-Puy',
#  'Vals-les-Bains',
#  'Valsemé',
#  'Valros',
#  'Valréas',
#  'Valras-Plage',
#  'Valprivas',
#  'Valojoulx',
#  'Valognes',
#  'Valmont',
#  'Valmondois',
#  'Vallon-en-Sully',
#  'Valloire',
#  'Valliquerville',
#  'Vallières',
#  'Vallet',
#  'Valleroy',
#  'Valleraugue',
#  'Valleiry',
#  'Vallauris',
#  'Vallabrix',
#  'Vallabrègues',
#  'Valignat',
#  'Valframbert',
#  'Valfin-lès-Saint-Claude',
#  'Valff',
#  'Valergues',
#  'Valenton',
#  'Valentigney',
#  'Valensole',
#  'Valencin',
#  'Arrondissement de Valenciennes',
#  'Valenciennes',
#  'Valence-sur-Baïse',
#  'Arrondissement de Valence',
#  'Valence',
#  'Valence',
#  'Valençay',
#  "Val d'Oise",
#  'Valdoie',
#  "Val-d'Isère",
#  'Val-de-Marne',
#  'Valbonne',
#  'Valbeleix',
#  'Valady',
#  'Val',
#  'Vaivre-et-Montoille',
#  'Vaison-la-Romaine',
#  'Vaires-sur-Marne',
#  'Vairé',
#  'Vains',
#  'Vailly-sur-Aisne',
#  'Vailhauquès',
#  'Vailhac',
#  'Vaiges',
#  'Vagney',
#  'Vacquiers',
#  'Vacqueyras',
#  'Vacon',
#  'Vacognes-Neuilly',
#  'Vabres',
#  'Vaas',
#  'Uzos',
#  'Uzeste',
#  'Uzès',
#  'Uzerche',
#  'Uzemain',
#  'Uzein',
#  'Uzan',
#  'Uxem',
#  'Uxegney',
#  'Ustaritz',
#  'Ussy',
#  'Usson-en-Forez',
#  'Usson-du-Poitou',
#  "Arrondissement d'Ussel",
#  'Ussel',
#  'Ussac',
#  'Us',
#  'Urzy',
#  'Urville-Nacqueville',
#  'Urt',
#  'Urrugne',
#  'Urou-et-Crennes',
#  'Urmatt',
#  'Uriménil',
#  'Urgons',
#  'Urepel',
#  'Urdos',
#  'Urdès',
#  'Urcuit',
#  'Urciers',
#  'Upie',
#  'Unverre',
#  'Unsac',
#  'Unieux',
#  'Ungersheim',
#  'Ully-Saint-Georges',
#  'Uhart-Cize',
#  'Ugine',
#  'Uffholtz',
#  'Uckange',
#  'Uchaux',
#  'Uchaud',
#  'Uchacq-et-Parentis',
#  'Uberach',
#  'Tursac',
#  'Turretot',
#  'Turquant',
#  'Turckheim',
#  'Tullins',
#  'Arrondissement de Tulle',
#  'Tulle',
#  'Tulette',
#  'Tuffé',
#  'Tucquegnieux',
#  'Truyes',
#  'Truttemer-le-Grand',
#  'Trungy',
#  'Trun',
#  'Truchtersheim',
#  'Arrondissement de Troyes',
#  'Troyes',
#  'Trouy',
#  'Trouville-sur-Mer',
#  'Troupenat',
#  'Trouillas',
#  'Trosly-Breuil',
#  'Tronville-en-Barrois',
#  'Troniçais',
#  'Tronget',
#  'Trois-Villes',
#  'Troissereux',
#  'Trois-Monts',
#  'Troisgots',
#  'Troarn',
#  'Trizay',
#  'Trizac',
#  'Trivis',
#  'Trith-Saint-Léger',
#  'Trilport',
#  'Triguères',
#  'Trignac',
#  'Trieux',
#  'Triel-sur-Seine',
#  'Trie-Château',
#  'Trie-sur-Baïse',
#  'Tricot',
#  'Tribehou',
#  'Triaize',
#  'Trézelles',
#  'Trévoux',
#  'Trévou-Tréguignec',
#  'Trévol',
#  'Trévé',
#  'Trets',
#  'Treteau',
#  'Tressin',
#  'Tresses',
#  'Tresserve',
#  'Tressange',
#  'Tresques',
#  'Tresbœuf',
#  'Trept',
#  'Tréprel',
#  'Tréon',
#  'Trentels',
#  'Trensacq',
#  'Trémuson',
#  'Trémons',
#  'Tréméven',
#  'Trémery',
#  'Trémentines',
#  'Tremblay-en-France',
#  'Tremblay',
#  'Trélon',
#  'Trelly',
#  'Trélivan',
#  'Trélissac',
#  'Trélévern',
#  'Trélazé',
#  'Treize-Septiers',
#  'Treillières',
#  'Treignat',
#  'Treignac',
#  'Trégunc',
#  'Tréguier',
#  'Trégastel',
#  'Treffléan',
#  'Treffiagat',
#  'Trédarzec',
#  'Trébeurden',
#  'Trèbes',
#  'Treban',
#  'Trappes',
#  'Trans-en-Provence',
#  'Trangé',
#  'Tramoyes',
#  'Traînou',
#  'Trailus',
#  'Tracy-le-Mont',
#  'Tracy-Bocage',
#  'Tracros',
#  'Touvre',
#  'Touvois',
#  'Toutlemonde',
#  'Toutainville',
#  'Toussus-le-Noble',
#  'Toussieu',
#  'Tourzel',
#  'Toury',
#  'Tourville-sur-Sienne',
#  'Tourville-sur-Odon',
#  'Tourville-sur-Arques',
#  'Tourville-la-Rivière',
#  'Tourves',
#  'Tourtrès',
#  'Tourtoirac',
#  'Tours-sur-Meymont',
#  'Tours-sur-Marne',
#  'Arrondissement de Tours',
#  'Tours',
#  'Tourriers',
#  'Tourrette-Levens',
#  'Tourouvre',
#  'Tournus',
#  'Tournon-Saint-Martin',
#  "Tournon-d'Agenais",
#  'Arrondissement de Tournon-sur-Rhône',
#  'Tournon-sur-Rhône',
#  'Tournières',
#  'Tournes',
#  'Tournemire',
#  'Tournehem-sur-la-Hem',
#  'Tournefeuille',
#  'Tournebu',
#  'Tournay-sur-Odon',
#  'Tournay',
#  'Tournan-en-Brie',
#  'Tournai-sur-Dive',
#  'Tourmi',
#  'Tourliac',
#  'Tourlaville',
#  'Tourgeville',
#  'Tourrettes-sur-Loup',
#  'Tourcoing',
#  'Tourbes',
#  'Touquin',
#  'Touquettes',
#  'Touques',
#  'Toulouzette',
#  'Arrondissement de Toulouse',
#  'Toulouse',
#  'Toulouges',
#  'Toulon-sur-Arroux',
#  'Toulon-sur-Allier',
#  'Arrondissement de Toulon',
#  'Toulon',
#  'Toulenne',
#  'Toulaud',
#  'Toulat',
#  'Arrondissement de Toul',
#  'Toul',
#  'Toufflers',
#  'Toucy',
#  'Tôtes',
#  'Tossiat',
#  'Tosse',
#  'Tortisambert',
#  'Tortezais',
#  'Tortebesse',
#  'Torsiac',
#  'Torreilles',
#  'Torra',
#  'Torigni-sur-Vire',
#  'Torfou',
#  'Tordouet',
#  'Torcy',
#  'Torcy',
#  'Torcé',
#  'Tonquédec',
#  'Tonneville',
#  'Tonnerre',
#  'Tonneins',
#  'Tonnay-Charente',
#  'Tonnay-Boutonne',
#  'Tomblaine',
#  'Tollevast',
#  'Toiras',
#  'Tocqueville',
#  'Tocane-Saint-Apre',
#  'Tizac-de-Lapouyade',
#  'Tizac-de-Curton',
#  'Tirepied',
#  'Tiranges',
#  'Tinténiac',
#  'Tinqueux',
#  'Tinlhat',
#  'Tinchebray',
#  'Tincave',
#  'Tilques',
#  'Tilly-sur-Seulles',
#  'Tilloy-lès-Mofflaines',
#  'Tillières-sur-Avre',
#  'Tillières',
#  'Tillé',
#  ...]

# %%
import requests
import json
import pandas as pd
from datetime import datetime

# Liste pour stocker les informations des villes
data_list = []
cities = ["Paris", "Marseille", "Lyon", "Toulouse", "Nice", "Nantes", "Strasbourg", "Montpellier", "Bordeaux", "Lille", "Rennes", "Reims", "Le Havre", "Saint-Etienne", "Toulon", "Grenoble", "Dijon", "Nîmes", "Angers", "Villeurbanne"]

# Requête pour chaque ville
for city in cities:
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}"
    response = requests.get(url)
    
    # Vérifier que la requête s'est bien passée
    if response.status_code == 200:
        data = json.loads(response.text)
        
        # Récupérer les informations
        current_temp = data["main"]["temp"] - 273.15
        feels_like_temp = data["main"]["feels_like"] - 273.15
        min_temp = data["main"]["temp_min"] - 273.15
        max_temp = data["main"]["temp_max"] - 273.15
        pressure = data["main"]["pressure"]
        humidity = data["main"]["humidity"]
        wind_speed = data["wind"]["speed"]
        wind_direction = data["wind"]["deg"]
        sunrise = datetime.fromtimestamp(data["sys"]["sunrise"]).strftime("%Y-%m-%d %H:%M:%S")
        sunset = datetime.fromtimestamp(data["sys"]["sunset"]).strftime("%Y-%m-%d %H:%M:%S")
        
        # Ajouter les informations à la liste
        data_list.append([city, current_temp, feels_like_temp, min_temp, max_temp, pressure, humidity, wind_speed, wind_direction, sunrise, sunset])
    
    else:
        print(f"Error: Request failed with status code {response.status_code}")

# Créer le DataFrame pandas
df = pd.DataFrame(data_list, columns=["City", "Current Temperature", "Feels Like Temperature", "Minimum Temperature", "Maximum Temperature", "Pressure", "Humidity", "Wind Speed", "Wind Direction", "Sunrise", "Sunset"])

# Exporter le DataFrame dans un fichier CSV
df.to_csv("weather_data.csv", index=False)
df
# Out:
#              City  Current Temperature  Feels Like Temperature  \
# 0           Paris                11.26                    9.77
# 1       Marseille                17.68                   16.42
# 2            Lyon                 8.31                    7.42
# 3        Toulouse                11.96                   10.93
# 4            Nice                 9.63                    8.13
# 5          Nantes                 7.96                    5.20
# 6      Strasbourg                 8.05                    4.53
# 7     Montpellier                17.89                   16.73
# 8        Bordeaux                13.15                   12.04
# 9           Lille                10.86                    9.20
# 10         Rennes                 9.31                    7.96
# 11          Reims                10.87                    9.32
# 12       Le Havre                 9.51                    6.92
# 13  Saint-Etienne                 6.62                    2.70
# 14         Toulon                18.22                   17.51
# 15       Grenoble                 2.54                   -0.08
# 16          Dijon                 6.93                    3.28
# 17          Nîmes                15.71                   14.51
# 18         Angers                11.00                    9.77
# 19   Villeurbanne                 9.50                    5.83
#
#     Minimum Temperature  Maximum Temperature  Pressure  Humidity  Wind Speed  \
# 0                 10.64                12.43      1025        51        6.69
# 1                 14.53                18.70      1010        35        2.24
# 2                  6.04                 8.61      1019        75        1.79
# 3                 11.56                12.65      1020        66        5.14
# 4                  8.90                10.34      1010        53        2.90
# 5                  7.81                 7.96      1025        76        4.63
# 6                  7.70                 8.49      1025        53        6.69
# 7                 17.29                18.05      1013        38        6.17
# 8                 13.15                15.19      1022        58        2.57
# 9                  8.85                12.15      1027        46        6.69
# 10                 9.02                11.43      1026        71        2.57
# 11                 9.41                10.88      1026        50        6.69
# 12                 9.51                10.86      1027        61        5.14
# 13                 6.62                 8.20      1019        87        6.69
# 14                16.81                22.74      1009        54        6.69
# 15                 2.54                 2.54      1017        93        2.57
# 16                 6.85                 9.06      1022        76        6.17
# 17                14.10                16.31      1013        45       10.29
# 18                 9.01                11.00      1024        62        4.84
# 19                 8.45                11.02      1019        78        8.75
#
#     Wind Direction              Sunrise               Sunset
# 0               50  2023-04-03 07:24:51  2023-04-03 20:22:48
# 1              340  2023-04-03 07:16:58  2023-04-03 20:05:29
# 2              343  2023-04-03 07:18:42  2023-04-03 20:11:05
# 3              280  2023-04-03 07:32:58  2023-04-03 20:21:56
# 4              208  2023-04-03 07:09:27  2023-04-03 19:58:59
# 5               60  2023-04-03 07:42:06  2023-04-03 20:37:00
# 6               60  2023-04-03 07:03:34  2023-04-03 20:00:56
# 7               10  2023-04-03 07:23:14  2023-04-03 20:12:11
# 8               50  2023-04-03 07:40:04  2023-04-03 20:31:01
# 9               50  2023-04-03 07:20:16  2023-04-03 20:21:42
# 10             100  2023-04-03 07:41:32  2023-04-03 20:38:14
# 11              80  2023-04-03 07:17:38  2023-04-03 20:16:09
# 12              70  2023-04-03 07:33:11  2023-04-03 20:32:23
# 13             340  2023-04-03 07:19:41  2023-04-03 20:11:33
# 14             240  2023-04-03 07:15:24  2023-04-03 20:03:35
# 15             336  2023-04-03 07:14:15  2023-04-03 20:05:32
# 16              30  2023-04-03 07:15:37  2023-04-03 20:10:42
# 17             360  2023-04-03 07:20:50  2023-04-03 20:10:16
# 18              51  2023-04-03 07:37:43  2023-04-03 20:33:07
# 19             350  2023-04-03 07:17:29  2023-04-03 20:09:54

# %%
import sqlite3

# Créer une connexion à la base de données
conn = sqlite3.connect('test.db')

# Insérer le DataFrame dans une table nommée 'personnes'
df.to_sql('meteo', conn, if_exists='replace', index=False)

# Fermer la connexion
conn.close()
